# %%
# !pip install fasttext-langdetect
# !pip install datasets
# Out:
# Requirement already satisfied: fasttext-langdetect in /usr/local/lib/python3.10/dist-packages (1.0.5)
# Requirement already satisfied: fasttext>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from fasttext-langdetect) (0.9.2)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.10/dist-packages (from fasttext-langdetect) (2.31.0)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.10/dist-packages (from fasttext>=0.9.1->fasttext-langdetect) (2.12.0)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext>=0.9.1->fasttext-langdetect) (67.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fasttext>=0.9.1->fasttext-langdetect) (1.25.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->fasttext-langdetect) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->fasttext-langdetect) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->fasttext-langdetect) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->fasttext-langdetect) (2024.2.2)
# Collecting datasets
#   Downloading datasets-2.19.0-py3-none-any.whl (542 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 10.7 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Collecting huggingface-hub>=0.21.2 (from datasets)
#   Downloading huggingface_hub-0.22.2-py3-none-any.whl (388 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.9/388.9 kB 14.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, dill, multiprocess, huggingface-hub, datasets
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.20.3
#     Uninstalling huggingface-hub-0.20.3:
#       Successfully uninstalled huggingface-hub-0.20.3
# Successfully installed datasets-2.19.0 dill-0.3.8 huggingface-hub-0.22.2 multiprocess-0.70.16 xxhash-3.4.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from datasets import Dataset

dataset_en = Dataset.from_json("/content/drive/MyDrive/2024/train/subtask_1/train.jsonl")

dataset_en
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-95e85e3ee6d1> in <cell line: 1>()
# ----> 1 from datasets import Dataset
#       2
#       3 dataset_en = Dataset.from_json("/content/drive/MyDrive/2024/train/subtask_1/train.jsonl")
#       4
#       5 dataset_en
#
# ModuleNotFoundError: No module named 'datasets'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#from langdetect import detect, detect_langs
from ftlangdetect import detect


# Assuming dataset_en is a list of texts
for text in dataset_en['text'][:20]:
    try:
        language = detect(text)
    except:
        language = "Error, could not detect"
    print(f"Text: {text}... \nDetected language: {language}\n")
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# Text: Es un tribunal de suprema instanza que forma part de la jurisdiccion española, i és el principal organe judicial de catalunya, nacionals i comarcals. constitucionalmente, és el tribunal especial d"exercic de la judiccia catalana, és el que interpreta i defini la llei espanyola, i anull·la la seva aplicació en qualsevol cas o circunstancia, mitjançant la reforma del sistema legal català. és, a més, el tribunal especial d"exercic de la judiccia nacional catalana, és el que interpreta i s"applique la lex catalana, i que de nova es defineix per la constitució espanyola. és també un tribunal de recursos de catalunya, a la qual té afegit l"exercici del seu mandat en el fet que, al desenvolupament dels règims de la central bank of spain i de l"agència tributària de catalunya, es van aplicar els recursos de catalunya en les seves tasques. així, és un organisme obert al reconeixement de l"autogovern de catalunya, i es considera com a un tribunal de recursos, fins que aprové la constitución espanyola. la seva accountability es controla per a la comissió nacional de la protecció de drets humans (cnpdh) i la consellera de les ciutades catalanes. els tribunals de l"alcalde, els tribunals de proximitat, els tribunals de les comarques de la generalitat, i, en el cas del pronunciamente de catalunya, els mitjans territorials, donen suport a l"tribunal suprem d"espanya. <!--this is a translation from catalan to english. please note that the machine translation may...
# Detected language: {'lang': 'ca', 'score': 0.9489762783050537}
#
# Text: Aixó de tindrer la platgeta tant prou era un privilegi, però tenieu dutxes?...
# Detected language: {'lang': 'ca', 'score': 0.954498827457428}
#
# Text: Doug mcadam es un científico estadista estadounidense que está relacionado con la aplicación de los resultados de las teorías de la acción política en la práctica de la democracia. doug mcadam es el director del center for data analysis at the university of washington, y el presidente del american political science association. mcadam es el autor de numerosos libros y folletos sobre la política, los estudios de la democracia y el análisis de datos. entre sus libros más conocidos están: *american power and the democratic puzzle* y *voice and equality*. en *american power and the democratic puzzle*, mcadam examina los factores que beneficiarán a los grupos políticamentos minoritarios en los estados unidos, es decir, cómo y cuándo lograrán los objetivos de los grupos políticos minoritarios en la democracia estatal. mcadam"s tesis principal es que la democracia funciona mejor cuando las oportunidades políticas abren las "vías de la delegación", es decir, cuando las personas o grupos políticos minoritarios puedan avanzar sus objetivos políticos a través de otras personas o grupos similares. mcadam describe diferentes casos clásicos...
# Detected language: {'lang': 'es', 'score': 0.9475117921829224}
#
# Text: El president de la generalitat, carles puigdemont, i la vicepresidenta del govern espanyol, soraya sáenz de santamaría, han coincidit avui en un dinar amb motiu de la celebració del trofeu conde de godó. l"esdeveniment, que se celebra cada any en el real club de tenis barcelona, ha reunit a diverses personalitats polítiques, empresarials i socials. entre elles, destaquen els noms de puigdemont i sáenz de santamaría, dos figures clau en el panorama polític actual. la presència d"ambdós dirigents en el mateix acte ha generat expectació i especulacions sobre una possible trobada entre ells, després de les tensions entre catalunya i l"estat espanyol arran del procés independentista. no obstant, segons fonts pròximes als dos polítics, el dinar ha transcorregut en un ambient de cordialitat i respecte mútu. tant puigdemont com sáenz de santamaría han intercanviat salutacions i han compartit taula durant el tradicional àpat que es serveix en aquesta ocasió. durant el discurs de benvinguda, el president del real club de tenis barcelona, albert agustí, ha destacat la importància de la convivència i del diàleg en els moments actuals. a més, ha mostrat el seu suport al torneig i ha agraït la presència de les autoritats en aquesta jornada esportiva tan especial. per la seva banda, puigdemont ha destacat la importància del trofeu conde de godó com a esdeveniment esportiu i ha felicitat els jugadors participants. a més, ha afegit que "en un acte com aquest, tots compartim una mateixa passió: el tennis". sáenz de santamaría, per la seva banda, ha volgut agrair l"organització del torneig i ha destacat que "això demostra que, malgrat les...
# Detected language: {'lang': 'ca', 'score': 0.9538456797599792}
#
# Text: Traídas de francia, tan estrafalarias que una de ellas, por ejemplo, tenía entretejido el pelo postizo de tal modo que formaba un gran velero con las velas desplegadas. un día, un grupo de personas que habían estado viajando desde francia llegó a la ciudad, y entre ellos había una joven que llevaba el pelo entretejido de tal manera que formaba un gran velero con las velas desplegadas. la gente estaba sorprendida y asombrada por el estilo de peinado de la joven, ya que nunca se había visto algo...
# Detected language: {'lang': 'es', 'score': 0.9931985139846802}
#
# Detected language: {'lang': 'ca', 'score': 0.957434892654419}
#
# Text: Paul simon is a great artist with multiple hits. he falls into a similar category to the beatles and beach boys in that he has so many hits he cannot have a good greatest hits album. however the hits on this album have great quality and are fun to listen. my personal favorites are "have a good time" and "fifty ways to leave your lover" and all the songs are all original recordings. good album for paul simon...
# Detected language: {'lang': 'en', 'score': 0.9664544463157654}
#
# Text: El museu d"art contemporani de barcelona (macba) es dedica a analitzar i explorar l"eclosió de l"art d"acció i la performance als anys noranta a espanya. aquesta època va marcar un punt d"inflexió en l"art contemporani del país, amb una explosió de creativitat i innovació que va desafiar les convencions establertes. l"exposició, que es podrà visitar fins al proper mes de juny, presenta una àmplia selecció d"obres representatives d"aquesta era. entre elles, trobarem performances, instal·lacions, vídeos i altres formats experimentals que mostren la diversitat i la riquesa de l"escena artística espanyola de la dècada dels noranta. durant aquesta dècada, els artistes espanyols van començar a utilitzar el seu cos com a eina d"expressió, recorrent a la performance i a l"art d"acció per traslladar els seus missatges. a través d"aquestes pràctiques, van ser capaços de qüestionar les normes socials i culturals de l"època, així com de denunciar les injustícies polítiques i socials. "l"art d"acció i la performance van suposar una ruptura total amb l"art tradicional", explica el comissari de l"exposició. "els artistes van abandonar el marc de l"obra d"art com a objecte per convertir-se ells mateixos en l"obra. això va permetre una comunicació més directa i potent amb el públic, que sovint es convertia en partícip de l"acció". l"exposició del macba ofereix una visió completa d"aquesta etapa crucial en la història de l"art espanyol. a través d"una selecció cuidada d"obres, els visitants podran comprendre millor com aquesta generació d"artistes va trencar amb les convencions i va obrir noves vies...
# Detected language: {'lang': 'ca', 'score': 0.9884491562843323}
#
# Text: R hoarsely, "don"t be frightened. father"s tumbled into the water. belike we may bring him round again. seth and me are going to carry him in. get a blanket and make it hot as the fire." in...
# Detected language: {'lang': 'en', 'score': 0.9829763770103455}
#
# Text: Produto chegou com display riscado e falhas na pintura. produto chegou com display riscado e falhas na pintura. produto chegou com display riscado e falhas na pintura...
# Detected language: {'lang': 'pt', 'score': 0.9709798693656921}
#
# Text: Temp: 18,6°c, viento: 32,4km/h s, hum: 49%, sensación: 11,8ºc, presión: 1013,0hpa rising slowly, lluvia hoy 0,0...
# Detected language: {'lang': 'es', 'score': 0.8047013878822327}
#
# Text: Sri lanka is set to return 21 containers of waste to britain after a two-year investigation showed the shipment contained a variety of hazardous waste, including hospital waste, incinerator rejects, and plastics. the decision comes after a long-running battle between the two countries over the fate of the containers, which were initially denied entry into sri lanka in 2019. the containers were originally imported to sri lanka from the uk in 2011 and 2012. but in 2019, when the containers were being transported to an inland state facility, the government of sri lanka noticed that they contained hazardous items, including some that were on the list of unwanted imports, and thus decided to return them to the uk. the uk government rejected the request, saying that the containers met international standards. sri lanka continued to contest the matter, and the uk agreed to re-examine the containers and conduct tests on their contents. the tests, carried out by the sri lankan government and the united nations" food and agriculture organization (fao), revealed that the waste contained a number of hazardous items, including sharp metal objects, hospital waste, and incinerator remains. sri lanka"s ministry of environment has said that the government will take all necessary measures to return the containers back to their country of origin and will cover all costs associated with their transportation, following discussions with the uk. the government also emphasized its commitment to taking firm action to ensure that such illegal waste shipments do not enter the country in the...
as, representando un dos pequenos arquipélagos con maior interese ecolóxico do mar mediterráneo. a illa de maior tamaño, coñecida como a "columbrete grande" ou "l"illa grossa", ten un perfil en forma de arco aberto, característico dunha grande actividade volcánica submarina. o carallot, cos seus 32 metros de altura, representa os restos da cheminea central dun volcán. ata que foron protexidas, constituían un campo de tiro da aviación e da mariña, feito que produciu a deterioración de moitos dos escollos que as forman. a isto uníronse as visitas incontroladas e a pesca furtiva....
# Detected language: {'lang': 'gl', 'score': 0.800862193107605}
#
# Text: """basque artikulu hau: lasioglossum figueresi lasioglossum hau buruzko lekuz aldetik, mahaigaindiko blokean, iparraldeko lurralde eta lurraldeetan, lehia lardo eta zizkaidoa eman. lasioglossum eta megachilenoak, gainako, ibaiako...
# Detected language: {'lang': 'eu', 'score': 0.8338809013366699}
#
# Text: Bactérias canibais podem ser a solução para combater superbactérias, dizem cientistas britânicos cientistas britânicos afirmam ter descoberto uma nova arma na luta contra as superbactérias. segundo eles, as bactérias canibais, que se alimentam de outros microorganismos da mesma espécie, podem ser a chave para combater infecções resistentes a antibióticos. a descoberta foi feita por pesquisadores da universidade de oxford, que realizaram testes em laboratório com diferentes tipos de bactérias. eles observaram que, quando expostas às bactérias canibais, as superbactérias eram rapidamente eliminadas. de acordo com os cientistas, as bactérias canibais produzem enzimas que são capazes de quebrar a parede celular das outras bactérias, o que leva à sua destruição. além disso, elas também produzem toxinas que atacam diretamente as superbactérias, causando sua morte. essa descoberta é muito importante, já que as superbactérias são um grande problema de saúde pública. devido à resistência aos antibióticos, essas bactérias podem ser difíceis de serem tratadas e causar infecções graves e até mesmo fatais. os cientistas alertam, no entanto, que mais pesquisas precisam ser realizadas antes que essa técnica possa ser aplicada em humanos. ainda é necessário entender melhor como as bactérias canibais funcionam e quais seriam os possíveis efeitos colaterais em pacientes. apesar disso, a descoberta é promissora e pode representar uma nova esperança na luta contra as superbactérias. os pesquisadores britânicos acreditam que, no futuro, essa técnica possa ser utilizada em conjunto com os antibióticos tradicionais, aumentando sua eficácia no combate às infecções. o estudo foi publicado na revista científica "nature communications" e já está despertando interesse em outros pesquisadores ao redor do mundo. espera-se que novos avanços sejam feitos nesse campo...
# Detected language: {'lang': 'pt', 'score': 0.9762551188468933}

# %%
# Initialize an empty dictionary to store the texts for each language
language_datasets = {}

# Assuming dataset_en is a list of texts
for text in dataset_en['text']:
    try:
        language = detect(text)
    except:
        language = "Error, could not detect"

    # If the language is not already a key in the dictionary, add it with an empty list as its value
    if language['lang'] not in language_datasets:
        language_datasets[language['lang']] = []

    # Append the text to the list of texts for its detected language
    language_datasets[language['lang']].append(text)

# %%
# Set your threshold
threshold = 1000

# Create a new dictionary with only the items where the length of the list is greater than or equal to the threshold
language_datasets = {language: texts for language, texts in language_datasets.items() if len(texts) >= threshold}

# Assuming language_datasets is your dictionary of languages and texts
for language, texts in language_datasets.items():
    print(f"Language: {language}, Number of texts: {len(texts)}")
# Out:
# Language: ca, Number of texts: 16413
# Language: es, Number of texts: 22353
# Language: gl, Number of texts: 11448
# Language: en, Number of texts: 25769
# Language: pt, Number of texts: 20034
# Language: eu, Number of texts: 13574
